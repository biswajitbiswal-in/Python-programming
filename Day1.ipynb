# %% [markdown]
# # Lab 1: Introduction to Python Syntax & Arithmetic
#
# Below are basic `print()` statements and arithmetic operation demonstrations.

# %%
print("hello world")
# Out:
# hello world

# %%
print("Name ->Biswajit Biswal")
print("Regd no - > 250142323")
print("Roll  no ->25")
print("Section - > Genius")
# Out:
# Name ->Biswajit Biswal
# Regd no - > 250142323
# Roll  no ->25
# Section - > Genius

# %%
print("4 + 5 =",4+5)
print("9 - 8 =",9-8)
print("8 / 8 = ",8/8)
print("8 // 3 = " ,8//3)
print("8 % 8 = ",8%8)
print("8 * 8 =",8*8) 
print("2 ^ 5 =",2**5)
# Out:
# 4 + 5 = 9
# 9 - 8 = 1
# 8 / 8 =  1.0
# 8 // 3 =  2
# 8 % 8 =  0
# 8 * 8 = 64
# 2 ^ 5 = 32

# %% [markdown]
# # Relational Operators

# %%
print("5 == 5 --->",5==5)
print("7 > 6 --->",7>6)
print("8 < 9 --->",8<9)
print("5 != 5 --->",5!=5)
print("4 >=4 ---->",4>=4)
# Out:
# 5 == 5 ---> True
# 7 > 6 ---> True
# 8 < 9 ---> True
# 5 != 5 ---> False
# 4 >=4 ----> True

# %% [markdown]
# # Logical Operators

# %%
print("true && true --- >",True & True)
print("true && false --- >",True & False)
#Logical or Operator
print("true | false --->",True | False)
print("true | true --->",True | True)
print("false | flase --->",False | False)
#Logical not
print("true != false --->",True != False)
print("true != true --->",True != True)

print("not true --->",not True)
print("not false --->",not False)
# Out:
# true && true --- > True
# true && false --- > False
# true | false ---> True
# true | true ---> True
# false | flase ---> False
# true != false ---> True
# true != true ---> False
# not true ---> False
# not false ---> True

# %%
x = -5
print(x)
# Out:
# -5

# %%
x = 10
x += 5
print(x)
# Out:
# 15
