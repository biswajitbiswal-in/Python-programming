# %% [markdown]
# 1. WAP to print your name 5 times

# %%
i = 0
while i<5:
     print("Biswajit")
     i+=1
# Out:
# Biswajit
# Biswajit
# Biswajit
# Biswajit
# Biswajit

# %% [markdown]
# 2. WAP to find sum of 1 to n

# %%
n = int(input("Enter the number"))
i = 0 
sum = 0 
while i<=n:
    sum +=i
    i+=1
print(sum)
# Out:
# Enter the number 1000000000
# 500000000500000000

# %% [markdown]
# 3. WAP to find sum of n different numbers

# %%
n = int(input("How many numbers you want to add"))
i = 0
sum = 0 
while i<n:
    a = int(input("enter the number"))
    sum +=a
    i += 1
print(sum)
# Out:
# How many numbers you want to add 1
# enter the number 2
# 2

# %%
# n = int(input("How many numbers you want to add"))
sum = 0 
while 1:
    a = int(input("enter the number"))
    sum += a
    if a == 0:
        break
print(sum)
# Out:
# enter the number 1
# enter the number 2
# enter the number 0
# 3

# %%
# n = int(input("How many numbers you want to add"))
choice = "yes"
sum = 0 
while choice == "yes":
    a = int(input("enter the number"))
    sum += a
    choice = input("do you want to add more num?")
    if a > 0:
        break
        
print(sum)
# Out:
# enter the number 1
# do you want to add more num? yes
# enter the number -1
# do you want to add more num? n
# 0

# %%
n = int(input("Enter the number"))
i = 1 
fac = 1 
while i<=n:
    fac *=i
    i+=1
print('factoral of n', n ," = ",fac)
print('No of digits = ',len(str(fac)))
# Out:
# Enter the number 500
# factoral of n 500  =  ...
# No of digits =  1135
