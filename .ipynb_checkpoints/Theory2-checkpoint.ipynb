# %% [markdown]
# # String and loops

# %%
a = "tititit"
c = 0
for i in range(1,len(a)):
    if a[i]=="i":
        c += 1 
print("I detected :",c,"Times")

        #or
s = "tititit"
d = 0
for i in s:
    if s=="i":
        d += 1 
print("I detected :",c,"Times")
# Out:
# I detected : 3 Times
# I detected : 3 Times

# %% [markdown]
# 1. WAP to take input your full adress and find how many vowels are there

# %%
adress = str(input("Enter your full adress"))
v= "aeiouAEIOU"
c = 0 
for i in adress:
    if i in v:
        print(i,end = ",")
        c+=1
print("\n","Vowel = ",c)

# %% [markdown]
# 1. download the song and find how many vowels are there
