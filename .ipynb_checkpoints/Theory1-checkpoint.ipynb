# %% [markdown]
# # Python Strings
#
# ## 1. Introduction to Strings

# %% [markdown]
# ## Definition
#
# A **string** in Python is a sequence of characters enclosed within single quotes (`'...'`), double quotes (`"..."`), or triple quotes (`'''...'''` / `"""..."""`). Strings are **immutable**, meaning their contents cannot be changed after creation.
#
# ---
#
# ## Examples
#
# ### Basic Strings
# ```python
# # Single and double quotes work identically
# text_single = 'Hello, World!'
# text_double = "Python Programming"
#
# print(text_single)
# print(text_double)

# %%
s = "#GIFT 1234"
print(s)
print(len(s))
print(type(s))
print(s[0])
# Out:
# #GIFT 1234
# 10
# <class 'str'>
# #

# %% [markdown]
# ### Substring and Slicing
#
# **Slicing Syntax:** `string[start:stop:step]`
# * `start`: Beginning index (inclusive, defaults to `0`)
# * `stop`: Ending index (exclusive, defaults to end of string)
# * `step`: Index step size (defaults to `1`)
#
# ---
#
# #### Examples
#
# ```python
# s = "#GIFT 1234"
#
# # 1. Extract "#GIFT"
# print(s[0:5])  # Output: '#GIFT'
# print(s[:5])   # Output: '#GIFT'
#
# # 2. Extract "1234"
# print(s[6:])   # Output: '1234'
#
# # 3. Reverse the string
# print(s[::-1]) # Output: '4321 TFIG#'

# %%
s = "#GIFT 1234"

# 1. Extract "#GIFT"
print(s[0:5])  # Output: '#GIFT'
print(s[:5])   # Output: '#GIFT'

# 2. Extract "1234"
print(s[6:])   # Output: '1234'

# 3. Reverse the string
print(s[::-1]) # Output: '4321 TFIG#'
# Out:
# #GIFT
# #GIFT
# 1234
# 4321 TFIG#
