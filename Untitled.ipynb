# %%
print("hello world")
# Out:
# hello world

# %%
print("Name ->Biswajit Biswal")
print("Regd no - > 250142323")
print("Roll  no ->25")
print("Section - > Genius")
# Out:
# Name ->Biswajit Biswal
# Regd no - > 250142323
# Roll  no ->25
# Section - > Genius
